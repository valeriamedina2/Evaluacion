# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Evaluacion/blob/main/espa%C3%B1a_Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Extacccion de caracteristicas**

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 3.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2973 sha256=1b76992c840b248a194e4c3cf8b93c46989372212c6a03e148d7c1a8931daa20
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
from seaborn import load_dataset
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bd533e48-e850-4f4e-bfeb-3e25caa731e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd533e48-e850-4f4e-bfeb-3e25caa731e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo 
df= pd.read_csv('valores_nulos_españa.csv')
# Out:
# <ipython-input-4-884061716583>:2: DtypeWarning: Columns (0,1,3,4,5,6,7,8,10,11,12,13,15,17,19,20,21,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('valores_nulos_españa.csv')

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19656 entries, 0 to 19655
# Data columns (total 77 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    19656 non-null  object
#  1   id                                            19656 non-null  object
#  2   host_listings_count                           19656 non-null  object
#  3   latitude                                      19656 non-null  object
#  4   longitude                                     19656 non-null  object
#  5   accommodates                                  19656 non-null  object
#  6   bathrooms                                     19656 non-null  object
#  7   bedrooms                                      19656 non-null  object
#  8   beds                                          19656 non-null  object
# ...

# %% [markdown]
# ##Extraccion de caracteristicas

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df)

# %%
#Analisis de la variable host_response_time
table1= freq_tbl(df['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623779         0.623842
# 1  within a few hours       2699    0.137312         0.761168
# 2        within a day       2188    0.111315         0.872494
# 3                  --       2088    0.106227         0.978732
# 4  a few days or more        418    0.021266         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623779         0.623842
# 1  within a few hours       2699    0.137312         0.761168
# 2        within a day       2188    0.111315         0.872494
# 3                  --       2088    0.106227         0.978732
# 4  a few days or more        418    0.021266         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour          12261    0.623779         0.623842
# within a few hours       2699    0.137312         0.761168
# within a day             2188    0.111315         0.872494
# --                       2088    0.106227         0.978732
# a few days or more        418    0.021266         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('respuesta del host ')
plt.xlabel('tiempo en contestar')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Analisis de la variable host_response_time
table2= freq_tbl(df['host_identity_verified'])
table2
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17276    0.878917         0.879007
# 1                      f       2261    0.115028         0.994047
# 2                     --        117    0.005952         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table2[table2['frequency']>1]
Filtro
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17276    0.878917         0.879007
# 1                      f       2261    0.115028         0.994047
# 2                     --        117    0.005952         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_identity_verified')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           17276    0.878917         0.879007
# f                            2261    0.115028         0.994047
# --                            117    0.005952         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Verificacion del host')
plt.xlabel('Verdadero | Falso ')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Analisis de la variable property_type
table3= freq_tbl(df['property_type'])
table3
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9339    0.475122         0.475170
# 1                   Entire home       3703    0.188390         0.663580
# 2                  Entire villa       1714    0.087200         0.750789
# 3                  Entire condo       1400    0.071225         0.822021
# 4                Entire cottage        549    0.027930         0.849954
# ..                          ...        ...         ...              ...
# 72                        Floor          1    0.000051         0.999796
# 73       Shared room in cottage          1    0.000051         0.999847
# 74  Shared room in nature lodge          1    0.000051         0.999898
# 75      Private room in pension          1    0.000051         0.999949
# 76     Entire bed and breakfast          1    0.000051         1.000000
#
# [77 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>1]
Filtro
# Out:
#                        property_type  frequency  percentage  cumulative_perc
# 0                 Entire rental unit       9339    0.475122         0.475170
# 1                        Entire home       3703    0.188390         0.663580
# 2                       Entire villa       1714    0.087200         0.750789
# 3                       Entire condo       1400    0.071225         0.822021
# 4                     Entire cottage        549    0.027930         0.849954
# ..                               ...        ...         ...              ...
# 61          Private room in windmill          2    0.000102         0.999033
# 62              Private room in boat          2    0.000102         0.999135
# 63              Private room in barn          2    0.000102         0.999237
# 64  Shared room in bed and breakfast          2    0.000102         0.999339
# 65              Private room in loft          2    0.000102         0.999440
#
# [66 rows x 4 columns]

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                                   frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                     9339    0.475122         0.475170
# Entire home                            3703    0.188390         0.663580
# Entire villa                           1714    0.087200         0.750789
# Entire condo                           1400    0.071225         0.822021
# Entire cottage                          549    0.027930         0.849954
# ...                                     ...         ...              ...
# Private room in windmill                  2    0.000102         0.999033
# Private room in boat                      2    0.000102         0.999135
# Private room in barn                      2    0.000102         0.999237
# Shared room in bed and breakfast          2    0.000102         0.999339
# Private room in loft                      2    0.000102         0.999440
#
# [66 rows x 3 columns]

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Analisis de la variable has_availability
table4= freq_tbl(df['has_availability'])
table4
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      19595    0.996897         0.996998
# 1                f         59    0.003002         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>1]
Filtro
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      19595    0.996897         0.996998
# 1                f         59    0.003002         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('has_availability')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# has_availability
# t                     19595    0.996897         0.996998
# f                        59    0.003002         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Analisis de la variable instant_bookable
table5= freq_tbl(df['instant_bookable'])
table5
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                t      10681    0.543396         0.543452
# 1                f       8973    0.456502         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>1]
Filtro
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                t      10681    0.543396         0.543452
# 1                f       8973    0.456502         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('instant_bookable')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# instant_bookable
# t                     10681    0.543396         0.543452
# f                      8973    0.456502         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
