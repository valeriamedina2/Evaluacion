# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Evaluacion/blob/main/mexico_Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Extacccion de caracteristicas**

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting funpymodeling
#   Downloading funpymodeling-0.1.7-py3-none-any.whl (6.4 kB)
# Collecting seaborn<0.11.0,>=0.10.1
#   Downloading seaborn-0.10.1-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0.0,>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (1.5.3)
# Collecting sklearn<0.1,>=0.0
#   Downloading sklearn-0.0.post4.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2.0.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (1.22.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from funpymodeling) (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.2.2->funpymodeling) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.5->funpymodeling) (2022.7.1)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from seaborn<0.11.0,>=0.10.1->funpymodeling) (1.10.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.2.2->funpymodeling) (1.16.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2973 sha256=d353182d49e482490f996083e4c0e38075d3805f63e72714073fa447cf838b92
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# Installing collected packages: sklearn, seaborn, funpymodeling
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed funpymodeling-0.1.7 seaborn-0.10.1 sklearn-0.0.post4

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
from seaborn import load_dataset
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo 
df= pd.read_csv('valores_nulos_mexico.csv')

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3522 entries, 0 to 3521
# Data columns (total 77 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    3522 non-null   int64
#  1   id                                            3522 non-null   int64
#  2   host_listings_count                           3522 non-null   int64
#  3   latitude                                      3522 non-null   float64
#  4   longitude                                     3522 non-null   float64
#  5   accommodates                                  3522 non-null   float64
#  6   bathrooms                                     3522 non-null   float64
#  7   bedrooms                                      3522 non-null   float64
#  8   beds                                          3522 non-null   float64
#  9   price                                         3522 non-null   object
#  10  minimum_nights                                3522 non-null   float64
#  11  maximum_nights                                3522 non-null   float64
#  12  minimum_minimum_nights                        3522 non-null   float64
#  13  maximum_minimum_nights                        3522 non-null   float64
#  14  minimum_maximum_nights                        3522 non-null   float64
#  15  maximum_maximum_nights                        3522 non-null   float64
#  16  minimum_nights_avg_ntm                        3522 non-null   float64
#  17  maximum_nights_avg_ntm                        3522 non-null   float64
#  18  calendar_updated                              3522 non-null   object
#  19  availability_30                               3522 non-null   float64
#  20  availability_60                               3522 non-null   float64
#  21  availability_90                               3522 non-null   float64
#  22  availability_365                              3522 non-null   float64
#  23  number_of_reviews                             3522 non-null   float64
#  24  number_of_reviews_ltm                         3522 non-null   float64
#  25  number_of_reviews_l30d                        3522 non-null   float64
#  26  review_scores_rating                          3522 non-null   float64
#  27  review_scores_accuracy                        3522 non-null   float64
#  28  review_scores_cleanliness                     3522 non-null   float64
#  29  review_scores_checkin                         3522 non-null   float64
#  30  review_scores_communication                   3522 non-null   float64
#  31  review_scores_location                        3522 non-null   float64
#  32  review_scores_value                           3522 non-null   float64
#  33  calculated_host_listings_count                3522 non-null   float64
#  34  calculated_host_listings_count_entire_homes   3522 non-null   float64
#  35  calculated_host_listings_count_private_rooms  3522 non-null   float64
#  36  calculated_host_listings_count_shared_rooms   3522 non-null   float64
#  37  reviews_per_month                             3522 non-null   float64
#  38  id.1                                          3522 non-null   int64
#  39  listing_url                                   3522 non-null   object
#  40  scrape_id                                     3522 non-null   int64
#  41  last_scraped                                  3522 non-null   object
#  42  source                                        3522 non-null   object
#  43  name                                          3522 non-null   object
#  44  description                                   3522 non-null   object
#  45  neighborhood_overview                         3522 non-null   object
#  46  picture_url                                   3522 non-null   object
#  47  host_id                                       3522 non-null   int64
#  48  host_url                                      3522 non-null   object
#  49  host_name                                     3522 non-null   object
#  50  host_since                                    3522 non-null   object
#  51  host_location                                 3522 non-null   object
#  52  host_about                                    3522 non-null   object
#  53  host_response_time                            3522 non-null   object
#  54  host_is_superhost                             3522 non-null   object
#  55  host_thumbnail_url                            3522 non-null   object
#  56  host_picture_url                              3522 non-null   object
#  57  host_neighbourhood                            3522 non-null   object
#  58  host_verifications                            3522 non-null   object
#  59  host_has_profile_pic                          3522 non-null   object
#  60  host_identity_verified                        3522 non-null   object
#  61  neighbourhood                                 3522 non-null   object
#  62  neighbourhood_cleansed                        3522 non-null   object
#  63  neighbourhood_group_cleansed                  3522 non-null   object
#  64  property_type                                 3522 non-null   object
#  65  room_type                                     3522 non-null   object
#  66  bathrooms.1                                   3522 non-null   float64
#  67  bathrooms_text                                3522 non-null   object
#  68  bedrooms.1                                    3522 non-null   float64
#  69  amenities                                     3522 non-null   object
#  70  calendar_updated.1                            3522 non-null   object
#  71  has_availability                              3522 non-null   object
#  72  calendar_last_scraped                         3522 non-null   object
#  73  first_review                                  3522 non-null   object
#  74  last_review                                   3522 non-null   object
#  75  license                                       3522 non-null   float64
#  76  instant_bookable                              3522 non-null   object
# dtypes: float64(36), int64(6), object(35)
# memory usage: 2.1+ MB

# %% [markdown]
# ##Extraccion de caracteristicas

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(df)

# %%
#Analisis de la variable host_response_time
table1= freq_tbl(df['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       1990    0.565020         0.565020
# 1                  --        646    0.183419         0.748438
# 2  within a few hours        440    0.124929         0.873367
# 3        within a day        298    0.084611         0.957978
# 4  a few days or more        148    0.042022         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       1990    0.565020         0.565020
# 1                  --        646    0.183419         0.748438
# 2  within a few hours        440    0.124929         0.873367
# 3        within a day        298    0.084611         0.957978
# 4  a few days or more        148    0.042022         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour           1990    0.565020         0.565020
# --                        646    0.183419         0.748438
# within a few hours        440    0.124929         0.873367
# within a day              298    0.084611         0.957978
# a few days or more        148    0.042022         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('respuesta del host ')
plt.xlabel('tiempo en contestar')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Analisis de la variable host_response_time
table2= freq_tbl(df['host_identity_verified'])
table2
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       3103    0.881034         0.881034
# 1                      f        419    0.118966         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table2[table2['frequency']>1]
Filtro
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       3103    0.881034         0.881034
# 1                      f        419    0.118966         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_identity_verified')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                            3103    0.881034         0.881034
# f                             419    0.118966         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Verificacion del host')
plt.xlabel('Verdadero | Falso ')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Analisis de la variable property_type
table3= freq_tbl(df['property_type'])
table3

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>1]
Filtro

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('property_type')
Filtro_index
# Out:
#                                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                       1290    0.366269         0.366269
# Private room in rental unit               578    0.164111         0.530380
# Private room in home                      452    0.128336         0.658717
# Entire condo                              273    0.077513         0.736229
# Entire loft                               253    0.071834         0.808064
# Private room in condo                     118    0.033504         0.841567
# Entire home                               102    0.028961         0.870528
# Entire serviced apartment                  94    0.026689         0.897217
# Entire guest suite                         44    0.012493         0.909710
# Private room in guest suite                33    0.009370         0.919080
# Private room in loft                       32    0.009086         0.928166
# Private room in serviced apartment         26    0.007382         0.935548
# Entire guesthouse                          25    0.007098         0.942646
# Private room in bed and breakfast          24    0.006814         0.949461
# Room in boutique hotel                     21    0.005963         0.955423
# Private room in guesthouse                 21    0.005963         0.961386
# Shared room in rental unit                 16    0.004543         0.965928
# Room in serviced apartment                 15    0.004259         0.970187
# Private room in townhouse                  14    0.003975         0.974162
# Entire townhouse                           14    0.003975         0.978137
# Room in aparthotel                         11    0.003123         0.981261
# Private room                                9    0.002555         0.983816
# Shared room in home                         8    0.002271         0.986087
# Private room in hostel                      6    0.001704         0.987791
# Tiny home                                   5    0.001420         0.989211
# Entire place                                5    0.001420         0.990630
# Private room in tiny home                   4    0.001136         0.991766
# Shared room in condo                        3    0.000852         0.992618
# Entire cabin                                3    0.000852         0.993470
# Shared room in hostel                       3    0.000852         0.994321
# Entire hostel                               2    0.000568         0.994889
# Entire bungalow                             2    0.000568         0.995457
# Shared room in guesthouse                   2    0.000568         0.996025
# Room in bed and breakfast                   2    0.000568         0.996593
# Private room in farm stay                   2    0.000568         0.997161
# Shared room in guest suite                  2    0.000568         0.997729

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Tipo de propiedad')
plt.ylabel('Frecuencia')

# %%
#Analisis de la variable has_availability
table4= freq_tbl(df['has_availability'])
table4
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       3510    0.996593         0.996593
# 1                f         11    0.003123         0.999716
# 2                0          1    0.000284         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>1]
Filtro
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       3510    0.996593         0.996593
# 1                f         11    0.003123         0.999716

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('has_availability')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# has_availability
# t                      3510    0.996593         0.996593
# f                        11    0.003123         0.999716

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Analisis de la variable instant_bookable
table5= freq_tbl(df['instant_bookable'])
table5
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       2638    0.749006         0.749006
# 1                t        883    0.250710         0.999716
# 2                0          1    0.000284         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>1]
Filtro
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       2638    0.749006         0.749006
# 1                t        883    0.250710         0.999716

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('instant_bookable')
Filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# instant_bookable
# f                      2638    0.749006         0.749006
# t                       883    0.250710         0.999716

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
