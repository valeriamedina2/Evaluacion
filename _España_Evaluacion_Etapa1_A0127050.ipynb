# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Evaluacion/blob/main/_Espa%C3%B1a_Evaluacion_Etapa1_A0127050.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Etapa 1**
# ##Valeria Medina
# ##Datos España

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leemos el codigo 
df= pd.read_csv("Girona_España.csv", encoding = 'unicode_escape')
df
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 2      1.212820e+06             https://www.airbnb.com/rooms/1212820
# 3      7.516380e+05              https://www.airbnb.com/rooms/751638
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# ...             ...                                              ...
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19652  8.584110e+17  https://www.airbnb.com/rooms/858410917126332945
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 0      2.023030e+13   31/03/2023      city scrape
# ...

# %%
df.head()
# Out:
#           id                           listing_url     scrape_id last_scraped  \
# 0    14551.0    https://www.airbnb.com/rooms/14551  2.023030e+13   31/03/2023
# 1  1205757.0  https://www.airbnb.com/rooms/1205757  2.023030e+13   31/03/2023
# 2  1212820.0  https://www.airbnb.com/rooms/1212820  2.023030e+13   01/04/2023
# 3   751638.0   https://www.airbnb.com/rooms/751638  2.023030e+13   31/03/2023
# 4    41342.0    https://www.airbnb.com/rooms/41342  2.023030e+13   01/04/2023
#
#             source                                      name  \
# 0      city scrape  Cozy & Colorful by Nature (Private Room)
# 1      city scrape       HabitaciÃ³n doble + baÃ±o y terraza
# 2      city scrape       Apartment port de rei stunning wiew
# 3      city scrape       Room Limon - Casa Pati de lÂ´Albera
# 4  previous scrape         Beachfront Tamariua (Costa Brava)
#
#                                          description  \
# 0  Up in the hill of MontjuÃ¯c (a mountain overlo...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19655 entries, 0 to 19654
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            19655 non-null  float64
#  1   listing_url                                   19655 non-null  object
#  2   scrape_id                                     19655 non-null  float64
#  3   last_scraped                                  19655 non-null  object
#  4   source                                        19655 non-null  object
#  5   name                                          19655 non-null  object
#  6   description                                   19632 non-null  object
#  7   neighborhood_overview                         8342 non-null   object
#  8   picture_url                                   19655 non-null  object
# ...

# %%
#Identificar los valores nulos por columna 
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               5227
# Length: 75, dtype: int64

# %%
valores_nulos.to_csv("valores_nulos.csv")

# %%
#Identificar valores nulos por dataframe
valores_nulos= df.isnull().sum().sum()
valores_nulos
# Out:
# 174630

# %%
#Decidimos ustituir valores nulos por un string en  concreto ya que es informacion cualitativa que no se puede sustituir por un valor numerico 

df["description"] =df["description"].fillna("--") 
df["neighborhood_overview"] =df["neighborhood_overview"].fillna("--")
df["host_location"] =df["host_location"].fillna("--") 
df["host_name"] =df["host_name"].fillna("--") 
df["host_since"] =df["host_since"].fillna("--") 
df["host_location"] =df["host_location"].fillna("--") 
df["host_about"] =df["host_about"].fillna("--") 
df["host_response_time"] =df["host_response_time"].fillna("--") 
df["host_response_rate"] =df["host_response_rate"].fillna("--") 
df["host_acceptance_rate"] =df["host_acceptance_rate"].fillna("--") 
df["host_is_superhost"] =df["host_is_superhost"].fillna("--") 
df["host_thumbnail_url"] =df["host_thumbnail_url"].fillna("--") 
df["host_neighbourhood"] =df["host_neighbourhood"].fillna("--") 
df["host_picture_url"] =df["host_picture_url"].fillna("--") 
df["neighbourhood"] =df["neighbourhood"].fillna("--") 
df["host_listings_count"] =df["host_listings_count"].fillna("--") 
df["host_total_listings_count"] =df["host_total_listings_count"].fillna("--") 
df["neighbourhood_group_cleansed"] =df["neighbourhood_group_cleansed"].fillna("--") 
df["host_has_profile_pic"] =df["host_has_profile_pic"].fillna("--") 
df["host_identity_verified"] =df["host_identity_verified"].fillna("--") 
df["neighbourhood_group_cleansed"] =df["neighbourhood_group_cleansed"].fillna("--") 
df["bathrooms_text"] =df["bathrooms_text"].fillna("--") 
df["last_review"] =df["last_review"].fillna("--") 
df["first_review"] =df["first_review"].fillna("--") 
df["calendar_updated"] =df["calendar_updated"].fillna("--")

# %%
#Verificamos los valores nulos no numericos 
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               5227
# Length: 75, dtype: int64

# %%
valores_nulos= df.isnull().sum().sum()
valores_nulos
# Out:
# 63552

# %%
#Los valores numericos los llenamos con un 0 para no alterar los resultados 
df= df.fillna(0)

# %%
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %%
valores_nulos= df.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# ##Metodo de desviacion estandar

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
from seaborn import load_dataset
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
num_df=df.drop(['listing_url','scrape_id','last_scraped','source','name','description','neighborhood_overview', 'picture_url','host_id','host_url','host_name','host_since','host_location','host_about','host_response_time','host_response_rate','host_acceptance_rate','host_is_superhost', 'host_thumbnail_url','host_picture_url','host_neighbourhood','host_total_listings_count','host_verifications', 'host_has_profile_pic', 'host_identity_verified','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','property_type','room_type','bathrooms_text','amenities','has_availability','calendar_last_scraped','first_review','last_review','license','instant_bookable',], axis=1)
num_df
# Out:
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 1.0  41.996500   2.836460             2
# 1      1.205757e+06                 1.0  41.793040   2.774120             2
# 2      1.212820e+06                 2.0  42.112840   3.166700             4
# 3      7.516380e+05                 6.0  42.369580   2.980300             2
# 4      4.134200e+04                 2.0  42.346550   3.204630             4
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                34.0  41.957265   3.201288             8
# 19651  8.583960e+17                 3.0  41.699070   2.844080             4
# 19652  8.584110e+17                 9.0  41.813720   3.064465             4
# 19653  8.584180e+17               111.0  41.809375   3.053910             4
# 19654  8.584240e+17                 9.0  41.810169   3.066358             5
#
# ...

# %%
cuali=df.drop(['host_response_rate'	,'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count','latitude','longitude','accommodates','beds','price','minimum_nights','maximum_nights','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','availability_30','availability_60','availability_90','availability_365','number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','reviews_per_month'], axis=1)
cuali
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 2      1.212820e+06             https://www.airbnb.com/rooms/1212820
# 3      7.516380e+05              https://www.airbnb.com/rooms/751638
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# ...             ...                                              ...
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19652  8.584110e+17  https://www.airbnb.com/rooms/858410917126332945
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 0      2.023030e+13   31/03/2023      city scrape
# ...

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=num_df
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido id                                              1.145731e+18
# latitude                                        4.269221e+01
# longitude                                       3.796862e+00
# accommodates                                    1.357642e+01
# bathrooms                                       0.000000e+00
# bedrooms                                        6.744842e+00
# beds                                            1.134397e+01
# minimum_nights                                  6.165308e+01
# maximum_nights                                  2.126503e+03
# minimum_minimum_nights                          3.376581e+01
# maximum_minimum_nights                          8.979727e+01
# minimum_maximum_nights                          2.150788e+03
# maximum_maximum_nights                          2.153494e+03
# minimum_nights_avg_ntm                          4.942380e+01
# maximum_nights_avg_ntm                          2.094140e+03
# ...

# %%
#Encontramos Outliers del Dataframe
outliers= num_df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-62-b0bbabfe39cf>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= num_df[(y>Limite_Superior)|(y<Limite_Inferior)]
#        id host_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0     NaN                 NaN       NaN        NaN           NaN        NaN
# 1     NaN                 NaN       NaN        NaN           NaN        NaN
# 2     NaN                 NaN       NaN        NaN           NaN        NaN
# 3     NaN                 NaN       NaN        NaN           NaN        NaN
# 4     NaN                 NaN       NaN        NaN           NaN        NaN
# ...    ..                 ...       ...        ...           ...        ...
# 19650 NaN                 NaN       NaN        NaN           NaN        NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= num_df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-63-c4fcc73624ed>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= num_df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 NaN  41.996500   2.836460           2.0
# 1      1.205757e+06                 NaN  41.793040   2.774120           2.0
# 2      1.212820e+06                 NaN  42.112840   3.166700           4.0
# 3      7.516380e+05                 NaN  42.369580   2.980300           2.0
# 4      4.134200e+04                 NaN  42.346550   3.204630           4.0
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                 NaN  41.957265   3.201288           8.0
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=num_df.isnull().sum()
valores_nulos
# Out:
# id                                              0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=num_df.copy()
data_clean=data_clean.fillna(round(num_df.mean(),1))
data_clean
# Out:
# <ipython-input-65-e2c83ea144dd>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=data_clean.fillna(round(num_df.mean(),1))
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 1.0  41.996500   2.836460             2
# 1      1.205757e+06                 1.0  41.793040   2.774120             2
# 2      1.212820e+06                 2.0  42.112840   3.166700             4
# 3      7.516380e+05                 6.0  42.369580   2.980300             2
# 4      4.134200e+04                 2.0  42.346550   3.204630             4
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                34.0  41.957265   3.201288             8
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# id                                              0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
# Unimos los datas con el dataframe
limpios_desv = pd.concat([num_df,cuali], axis=1)
limpios_desv
# Out:
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 1.0  41.996500   2.836460             2
# 1      1.205757e+06                 1.0  41.793040   2.774120             2
# 2      1.212820e+06                 2.0  42.112840   3.166700             4
# 3      7.516380e+05                 6.0  42.369580   2.980300             2
# 4      4.134200e+04                 2.0  42.346550   3.204630             4
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                34.0  41.957265   3.201288             8
# 19651  8.583960e+17                 3.0  41.699070   2.844080             4
# 19652  8.584110e+17                 9.0  41.813720   3.064465             4
# 19653  8.584180e+17               111.0  41.809375   3.053910             4
# 19654  8.584240e+17                 9.0  41.810169   3.066358             5
#
# ...

# %%
#Corroboramos valores nulos 
limpios_desv=limpios_desv.isnull().sum()
limpios_desv
# Out:
# id                       0
# host_listings_count      0
# latitude                 0
# longitude                0
# accommodates             0
#                         ..
# calendar_last_scraped    0
# first_review             0
# last_review              0
# license                  0
# instant_bookable         0
# Length: 76, dtype: int64

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=num_df

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                                              1.430535e+18
# latitude                                        4.288548e+01
# longitude                                       3.623007e+00
# accommodates                                    9.000000e+00
# bathrooms                                       0.000000e+00
# bedrooms                                        6.000000e+00
# beds                                            9.500000e+00
# minimum_nights                                  1.100000e+01
# maximum_nights                                  2.722500e+03
# minimum_minimum_nights                          8.500000e+00
# maximum_minimum_nights                          1.300000e+01
# minimum_maximum_nights                          2.767500e+03
# maximum_maximum_nights                          2.265000e+03
# minimum_nights_avg_ntm                          9.500000e+00
# maximum_nights_avg_ntm                          2.265000e+03
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= num_df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# <ipython-input-70-12132436df6d>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers_iqr= num_df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
#        id host_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0     NaN                 NaN       NaN        NaN           NaN        NaN
# 1     NaN                 NaN       NaN        NaN           NaN        NaN
# 2     NaN                 NaN       NaN        NaN           NaN        NaN
# 3     NaN                 NaN       NaN        NaN           NaN        NaN
# 4     NaN                 NaN       NaN        NaN           NaN        NaN
# ...    ..                 ...       ...        ...           ...        ...
# 19650 NaN                 NaN       NaN        NaN           NaN        NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= num_df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
# <ipython-input-71-2db8a2765c89>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3_iqr= num_df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 NaN  41.996500   2.836460           2.0
# 1      1.205757e+06                 NaN  41.793040   2.774120           2.0
# 2      1.212820e+06                 NaN  42.112840   3.166700           4.0
# 3      7.516380e+05                 NaN  42.369580   2.980300           2.0
# 4      4.134200e+04                 NaN  42.346550   3.204630           4.0
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                 NaN  41.957265   3.201288           8.0
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=num_df.isnull().sum()
valores_nulos
# Out:
# id                                              0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=num_df.copy()
data5_iqr=data5_iqr.fillna(round(num_df.mean(),1))
data5_iqr
# Out:
# <ipython-input-73-9164b51ca533>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data5_iqr=data5_iqr.fillna(round(num_df.mean(),1))
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 1.0  41.996500   2.836460             2
# 1      1.205757e+06                 1.0  41.793040   2.774120             2
# 2      1.212820e+06                 2.0  42.112840   3.166700             4
# 3      7.516380e+05                 6.0  42.369580   2.980300             2
# 4      4.134200e+04                 2.0  42.346550   3.204630             4
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                34.0  41.957265   3.201288             8
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data5_iqr.isnull().sum()
valores_nulos
# Out:
# id                                              0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data6_iqr=cuali.copy()
data6_iqr=data5_iqr.fillna(round(cuali.mean()))
data6_iqr
# Out:
# <ipython-input-78-1c20573ef626>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data6_iqr=data5_iqr.fillna(round(cuali.mean()))
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 1.0  41.996500   2.836460             2
# 1      1.205757e+06                 1.0  41.793040   2.774120             2
# 2      1.212820e+06                 2.0  42.112840   3.166700             4
# 3      7.516380e+05                 6.0  42.369580   2.980300             2
# 4      4.134200e+04                 2.0  42.346550   3.204630             4
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                34.0  41.957265   3.201288             8
# ...

# %%
limpios_iqr = pd.concat([num_df, cuali], axis=1)
limpios_iqr
# Out:
#                  id host_listings_count   latitude  longitude  accommodates  \
# 0      1.455100e+04                 1.0  41.996500   2.836460             2
# 1      1.205757e+06                 1.0  41.793040   2.774120             2
# 2      1.212820e+06                 2.0  42.112840   3.166700             4
# 3      7.516380e+05                 6.0  42.369580   2.980300             2
# 4      4.134200e+04                 2.0  42.346550   3.204630             4
# ...             ...                 ...        ...        ...           ...
# 19650  8.583870e+17                34.0  41.957265   3.201288             8
# 19651  8.583960e+17                 3.0  41.699070   2.844080             4
# 19652  8.584110e+17                 9.0  41.813720   3.064465             4
# 19653  8.584180e+17               111.0  41.809375   3.053910             4
# 19654  8.584240e+17                 9.0  41.810169   3.066358             5
#
# ...

# %%
#Convertir DataFrame a CSV
limpios_iqr.to_csv("valores_nulos_españa.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("valores_nulos_españa.csv")
