# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Evaluacion/blob/main/filtro_california.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Filtro California

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leemos el codigo 
df= pd.read_csv("valores_nulos_california.csv")
df
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 0              0                    1  37.770280 -122.433170             3
# 1              1                    2  37.744740 -122.420890             4
# 2              2                   13  37.765550 -122.452130             1
# 3              3                    2  37.775640 -122.436420             4
# 4              4                    2  37.760300 -122.421970             3
# ...          ...                  ...        ...         ...           ...
# 6931        6931                    9  37.791994 -122.410000             2
# 6932        6932                    1  37.763060 -122.432023             2
# 6933        6933                    1  37.777633 -122.416478             1
# 6934        6934                    3  37.738325 -122.396603             2
# 6935        6935                    2  37.786442 -122.457006             2
#
# ...

# %% [markdown]
# ##host_acceptance_rate>50%

# %%
#No se encuentra esa columnas

# %% [markdown]
# ##Solo los registros con la categoria "host_is_superhost"

# %%
filtro2=df[df["host_is_superhost"] == "t"]
filtro2
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 0              0                    1  37.770280 -122.433170             3
# 4              4                    2  37.760300 -122.421970             3
# 7              7                    2  37.717500 -122.396980             2
# 8              8                    2  37.771960 -122.434770             5
# 9              9                    2  37.785460 -122.461480             6
# ...          ...                  ...        ...         ...           ...
# 6913        6913                    2  37.719700 -122.463300             2
# 6918        6918                   23  37.767920 -122.424256             1
# 6919        6919                   10  37.803929 -122.443176             4
# 6923        6923                    3  37.784690 -122.392874             2
# 6929        6929                   67  37.725231 -122.404776             2
#
#       bathrooms  bedrooms  beds    price  minimum_nights  ...  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("filtro2california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro2california.csv")

# %% [markdown]
# ##"not identity_verified"

# %%
filtro3=df[df["host_identity_verified"] == "f"]
filtro3
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 6              6                    1  37.747660 -122.420410             2
# 28            28                    1  37.749160 -122.429710             3
# 38            38                    1  37.751170 -122.425670             1
# 39            39                    1  37.803560 -122.404370             2
# 71            71                    5  37.792780 -122.410070            10
# ...          ...                  ...        ...         ...           ...
# 6885        6885                   24  37.800850 -122.433658             1
# 6905        6905                    2  37.731587 -122.496157             2
# 6931        6931                    9  37.791994 -122.410000             2
# 6932        6932                    1  37.763060 -122.432023             2
# 6933        6933                    1  37.777633 -122.416478             1
#
#       bathrooms  bedrooms  beds      price  minimum_nights  ...  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("filtro3california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro3california.csv")

# %% [markdown]
# ##property_type = "Private room' y 'Hotel Room"

# %%
filtro4=df[df["property_type"] == "Private room"]
#filtro4=df[df["property_type"] == "Hotel Room"]
filtro4
# Out:
#       Unnamed: 0  host_listings_count  latitude  longitude  accommodates  \
# 7              7                    2  37.71750 -122.39698             2
# 1575        1575                    3  37.75145 -122.40719             2
# 2049        2049                    7  37.79586 -122.41915             2
# 4014        4014                    7  37.79525 -122.41931             1
#
#       bathrooms  bedrooms  beds   price  minimum_nights  ...  \
# 7           0.0       1.0   1.0  $95.00               1  ...
# 1575        0.0       1.0   0.0  $69.00              30  ...
# 2049        0.0       0.0   1.0  $60.00              30  ...
# 4014        0.0       0.0   1.0  $56.00              30  ...
#
#         bathrooms_text  bedrooms.1  \
# 7     1.5 shared baths         1.0
# 1575     1 shared bath         1.0
# 2049    1 private bath         0.0
# 4014            1 bath         0.0
#
#                                               amenities  calendar_updated.1  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("filtro4california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro4california.csv")

# %% [markdown]
# ##bathroom>1

# %%
#Filtro por comparacion
filtro5=df[df["bathrooms"] > 1]
filtro5
# Out:
# Empty DataFrame
# ...

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("filtro5california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro5california.csv")

# %% [markdown]
# ##Precio mayor de 10000 y que sean de tipo "Entire Home"

# %%
filtro6=df[(df["price"] > "10000") & (df["room_type"] == "Entire Home/apt")]
filtro6
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ##registros review_scores_cleanliness>4.5

# %%
filtro7=df[df["review_scores_cleanliness"] > 4.5]
filtro7
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 0              0                    1  37.770280 -122.433170             3
# 1              1                    2  37.744740 -122.420890             4
# 3              3                    2  37.775640 -122.436420             4
# 4              4                    2  37.760300 -122.421970             3
# 5              5                    1  37.784400 -122.479320             4
# ...          ...                  ...        ...         ...           ...
# 6924        6924                    7  37.716079 -122.390953             2
# 6925        6925                    7  37.716214 -122.391460             2
# 6926        6926                    7  37.716070 -122.391170             2
# 6927        6927                   32  37.788619 -122.422556             2
# 6932        6932                    1  37.763060 -122.432023             2
#
#       bathrooms  bedrooms  beds    price  minimum_nights  ...  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("filtro7california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro7california.csv")

# %% [markdown]
# ##registros review_scores_value>4.9

# %%
filtro8=df[df["review_scores_value"] > 4.9]
filtro8
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 9              9                    2  37.785460 -122.461480             6
# 24            24                    2  37.762160 -122.450220             2
# 26            26                    1  37.762370 -122.429920             2
# 46            46                    2  37.717270 -122.436440             1
# 53            53                    1  37.744030 -122.417550             2
# ...          ...                  ...        ...         ...           ...
# 6920        6920                    9  37.801789 -122.426501             2
# 6924        6924                    7  37.716079 -122.390953             2
# 6925        6925                    7  37.716214 -122.391460             2
# 6927        6927                   32  37.788619 -122.422556             2
# 6932        6932                    1  37.763060 -122.432023             2
#
#       bathrooms  bedrooms  beds    price  minimum_nights  ...  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("filtro8california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro8california.csv")

# %% [markdown]
# ##availability_365<100

# %%
filtro9=df[df["availability_365"] < 100]
filtro9
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 5              5                    1  37.784400 -122.479320             4
# 8              8                    2  37.771960 -122.434770             5
# 9              9                    2  37.785460 -122.461480             6
# 11            11                    9  37.792330 -122.424310             1
# 15            15                    5  37.772520 -122.438460             2
# ...          ...                  ...        ...         ...           ...
# 6913        6913                    2  37.719700 -122.463300             2
# 6917        6917                    1  37.748247 -122.433441             2
# 6918        6918                   23  37.767920 -122.424256             1
# 6923        6923                    3  37.784690 -122.392874             2
# 6931        6931                    9  37.791994 -122.410000             2
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("filtro9california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro9california.csv")

# %% [markdown]
# ##host_response_time sea "within an hour"

# %%
filtro10=df[df["host_response_time"] == "within an hour"]
filtro10
# Out:
#       Unnamed: 0  host_listings_count   latitude   longitude  accommodates  \
# 0              0                    1  37.770280 -122.433170             3
# 2              2                   13  37.765550 -122.452130             1
# 4              4                    2  37.760300 -122.421970             3
# 5              5                    1  37.784400 -122.479320             4
# 12            12                    2  37.728330 -122.441250             2
# ...          ...                  ...        ...         ...           ...
# 6929        6929                   67  37.725231 -122.404776             2
# 6930        6930                    6  37.753771 -122.399004             1
# 6931        6931                    9  37.791994 -122.410000             2
# 6934        6934                    3  37.738325 -122.396603             2
# 6935        6935                    2  37.786442 -122.457006             2
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro10.to_csv("filtro10california.csv")
#descardar archivo filtrado en csv
from google.colab import files 
  
  
files.download("filtro10california.csv")
