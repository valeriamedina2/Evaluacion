# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriamedina2/Evaluacion/blob/main/california_Evaluacion_Etapa1_A0127050.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Etapa 1**
# ##Valeria Medina
# ##Datos California

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leemos el codigo 
df= pd.read_csv("California_EUA.csv", encoding = 'unicode_escape')
df
# Out:
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 1     5.858000e+03                https://www.airbnb.com/rooms/5858
# 2     8.142000e+03                https://www.airbnb.com/rooms/8142
# 3     8.339000e+03                https://www.airbnb.com/rooms/8339
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# ...            ...                                              ...
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
# 6933  8.180000e+17  https://www.airbnb.com/rooms/818396267693629070
# 6934  8.180000e+17  https://www.airbnb.com/rooms/818474518435984613
# 6935  8.190000e+17  https://www.airbnb.com/rooms/818887060432463897
#
#          scrape_id last_scraped       source  \
# 0     2.020000e+13   06/03/2023  city scrape
# 1     2.020000e+13   06/03/2023  city scrape
# ...

# %%
df.head()
# Out:
#     ï»¿id                        listing_url     scrape_id last_scraped  \
# 0   958.0   https://www.airbnb.com/rooms/958  2.020000e+13   06/03/2023
# 1  5858.0  https://www.airbnb.com/rooms/5858  2.020000e+13   06/03/2023
# 2  8142.0  https://www.airbnb.com/rooms/8142  2.020000e+13   06/03/2023
# 3  8339.0  https://www.airbnb.com/rooms/8339  2.020000e+13   06/03/2023
# 4  8739.0  https://www.airbnb.com/rooms/8739  2.020000e+13   06/03/2023
#
#         source                                               name  \
# 0  city scrape              Bright, Modern Garden Unit - 1BR/1BTH
# 1  city scrape                                 Creative Sanctuary
# 2  city scrape  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 3  city scrape                    Historic Alamo Square Victorian
# 4  city scrape                Mission Sunshine, with Private Bath
#
#                                          description  \
# 0  Our bright garden unit overlooks a lovely back...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6936 entries, 0 to 6935
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ï»¿id                                         6936 non-null   float64
#  1   listing_url                                   6936 non-null   object
#  2   scrape_id                                     6936 non-null   float64
#  3   last_scraped                                  6936 non-null   object
#  4   source                                        6936 non-null   object
#  5   name                                          6936 non-null   object
#  6   description                                   6889 non-null   object
#  7   neighborhood_overview                         4850 non-null   object
#  8   picture_url                                   6936 non-null   object
# ...

# %%
#Identificar los valores nulos por columna 
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                              0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1325
# Length: 75, dtype: int64

# %%
valores_nulos.to_csv("valores_nulos.csv")

# %%
#Identificar valores nulos por dataframe
valores_nulos= df.isnull().sum().sum()
valores_nulos
# Out:
# 48877

# %%
#Decidimos ustituir valores nulos por un string en  concreto ya que es informacion cualitativa que no se puede sustituir por un valor numerico 

df["description"] =df["description"].fillna("--") 
df["neighborhood_overview"] =df["neighborhood_overview"].fillna("--") 
df["host_location"] =df["host_location"].fillna("--") 
df["host_about"] =df["host_about"].fillna("--") 
df["host_response_time"] =df["host_response_time"].fillna("--") 
df["host_response_rate"] =df["host_response_rate"].fillna("--") 
df["host_acceptance_rate"] =df["host_acceptance_rate"].fillna("--") 
df["host_is_superhost"] =df["host_is_superhost"].fillna("--") 
df["host_neighbourhood"] =df["host_neighbourhood"].fillna("--") 
df["neighbourhood"] =df["neighbourhood"].fillna("--") 
df["neighbourhood_group_cleansed"] =df["neighbourhood_group_cleansed"].fillna("--") 
df["bathrooms_text"] =df["bathrooms_text"].fillna("--") 
df["last_review"] =df["last_review"].fillna("--") 
df["first_review"] =df["first_review"].fillna("--") 
df["calendar_updated"] =df["calendar_updated"].fillna("--")

# %%
#Verificamos los valores nulos no numericos 
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                              0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1325
# Length: 75, dtype: int64

# %%
valores_nulos= df.isnull().sum().sum()
valores_nulos
# Out:
# 14564

# %%
#Los valores numericos los llenamos con un 0 para no alterar los resultados 
df= df.fillna(0)

# %%
valores_nulos= df.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                           0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %%
valores_nulos= df.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# ##Metodo de desviacion estandar

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
from seaborn import load_dataset
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
num_df=df.drop(['ï»¿id','listing_url','scrape_id','last_scraped','source','name','description','neighborhood_overview', 'picture_url','host_id','host_url','host_name','host_since','host_location','host_about','host_response_time','host_response_rate','host_acceptance_rate','host_is_superhost', 'host_thumbnail_url','host_picture_url','host_neighbourhood','host_total_listings_count','host_verifications', 'host_has_profile_pic', 'host_identity_verified','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','property_type','room_type','bathrooms_text','amenities','has_availability','calendar_last_scraped','first_review','last_review','license','instant_bookable',], axis=1)
num_df
# Out:
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                       1  37.770280 -122.433170             3        0.0
# 1                       2  37.744740 -122.420890             4        0.0
# 2                      13  37.765550 -122.452130             1        0.0
# 3                       2  37.775640 -122.436420             4        0.0
# 4                       2  37.760300 -122.421970             3        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                    9  37.791994 -122.410000             2        0.0
# 6932                    1  37.763060 -122.432023             2        0.0
# 6933                    1  37.777633 -122.416478             1        0.0
# 6934                    3  37.738325 -122.396603             2        0.0
# 6935                    2  37.786442 -122.457006             2        0.0
#
#       bedrooms  beds    price  minimum_nights  maximum_nights  ...  \
# ...

# %%
cuali=df.drop(['host_response_rate'	,'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count','latitude','longitude','accommodates','beds','price','minimum_nights','maximum_nights','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','availability_30','availability_60','availability_90','availability_365','number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','reviews_per_month'], axis=1)
cuali
# Out:
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 1     5.858000e+03                https://www.airbnb.com/rooms/5858
# 2     8.142000e+03                https://www.airbnb.com/rooms/8142
# 3     8.339000e+03                https://www.airbnb.com/rooms/8339
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# ...            ...                                              ...
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
# 6933  8.180000e+17  https://www.airbnb.com/rooms/818396267693629070
# 6934  8.180000e+17  https://www.airbnb.com/rooms/818474518435984613
# 6935  8.190000e+17  https://www.airbnb.com/rooms/818887060432463897
#
#          scrape_id last_scraped       source  \
# 0     2.020000e+13   06/03/2023  city scrape
# 1     2.020000e+13   06/03/2023  city scrape
# ...

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=num_df
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# <ipython-input-85-6de38f69fdc5>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-85-6de38f69fdc5>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# ...

# %%
#Encontramos Outliers del Dataframe
outliers= num_df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-86-b0bbabfe39cf>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= num_df[(y>Limite_Superior)|(y<Limite_Inferior)]
#       host_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                     NaN       NaN        NaN           NaN        NaN
# 1                     NaN       NaN        NaN           NaN        NaN
# 2                     NaN       NaN        NaN           NaN        NaN
# 3                     NaN       NaN        NaN           NaN        NaN
# 4                     NaN       NaN        NaN           NaN        NaN
# ...                   ...       ...        ...           ...        ...
# 6931                  NaN       NaN        NaN           NaN        NaN
# 6932                  NaN       NaN        NaN           NaN        NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= num_df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-87-c4fcc73624ed>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= num_df[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                     1.0  37.770280 -122.433170           3.0        0.0
# 1                     2.0  37.744740 -122.420890           4.0        0.0
# 2                    13.0  37.765550 -122.452130           1.0        0.0
# 3                     2.0  37.775640 -122.436420           4.0        0.0
# 4                     2.0  37.760300 -122.421970           3.0        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                  9.0  37.791994 -122.410000           2.0        0.0
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=num_df.isnull().sum()
valores_nulos
# Out:
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# availability_60                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=num_df.copy()
data_clean=data_clean.fillna(round(num_df.mean(),1))
data_clean
# Out:
# <ipython-input-91-e2c83ea144dd>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=data_clean.fillna(round(num_df.mean(),1))
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                       1  37.770280 -122.433170             3        0.0
# 1                       2  37.744740 -122.420890             4        0.0
# 2                      13  37.765550 -122.452130             1        0.0
# 3                       2  37.775640 -122.436420             4        0.0
# 4                       2  37.760300 -122.421970             3        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                    9  37.791994 -122.410000             2        0.0
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# availability_60                                 0
# ...

# %%
# Unimos los datas con el dataframe
limpios_desv = pd.concat([num_df,cuali], axis=1)
limpios_desv
# Out:
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                       1  37.770280 -122.433170             3        0.0
# 1                       2  37.744740 -122.420890             4        0.0
# 2                      13  37.765550 -122.452130             1        0.0
# 3                       2  37.775640 -122.436420             4        0.0
# 4                       2  37.760300 -122.421970             3        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                    9  37.791994 -122.410000             2        0.0
# 6932                    1  37.763060 -122.432023             2        0.0
# 6933                    1  37.777633 -122.416478             1        0.0
# 6934                    3  37.738325 -122.396603             2        0.0
# 6935                    2  37.786442 -122.457006             2        0.0
#
#       bedrooms  beds    price  minimum_nights  maximum_nights  ...  \
# ...

# %%
#Corroboramos valores nulos 
limpios_desv=limpios_desv.isnull().sum()
limpios_desv
# Out:
# host_listings_count      0
# latitude                 0
# longitude                0
# accommodates             0
# bathrooms                0
#                         ..
# calendar_last_scraped    0
# first_review             0
# last_review              0
# license                  0
# instant_bookable         0
# Length: 75, dtype: int64

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=num_df

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_listings_count                               38.500000
# latitude                                          37.838593
# longitude                                       -122.362240
# accommodates                                       7.000000
# bathrooms                                          0.000000
# bedrooms                                           3.500000
# beds                                               3.500000
# minimum_nights                                    72.000000
# maximum_nights                                  2769.000000
# minimum_minimum_nights                            72.000000
# maximum_minimum_nights                            72.000000
# minimum_maximum_nights                          2677.500000
# maximum_maximum_nights                          2677.500000
# minimum_nights_avg_ntm                            72.000000
# maximum_nights_avg_ntm                          2677.500000
# ...

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= num_df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# <ipython-input-97-12132436df6d>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers_iqr= num_df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
#       host_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                     NaN       NaN        NaN           NaN        NaN
# 1                     NaN       NaN        NaN           NaN        NaN
# 2                     NaN       NaN        NaN           NaN        NaN
# 3                     NaN       NaN        NaN           NaN        NaN
# 4                     NaN       NaN        NaN           NaN        NaN
# ...                   ...       ...        ...           ...        ...
# 6931                  NaN       NaN        NaN           NaN        NaN
# 6932                  NaN       NaN        NaN           NaN        NaN
# ...

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= num_df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
# <ipython-input-98-2db8a2765c89>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3_iqr= num_df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                     1.0  37.770280 -122.433170           3.0        0.0
# 1                     2.0  37.744740 -122.420890           4.0        0.0
# 2                    13.0  37.765550 -122.452130           1.0        0.0
# 3                     2.0  37.775640 -122.436420           4.0        0.0
# 4                     2.0  37.760300 -122.421970           3.0        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                  9.0  37.791994 -122.410000           2.0        0.0
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=num_df.isnull().sum()
valores_nulos
# Out:
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# availability_60                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=num_df.copy()
data5_iqr=data5_iqr.fillna(round(num_df.mean(),1))
data5_iqr
# Out:
# <ipython-input-100-9164b51ca533>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data5_iqr=data5_iqr.fillna(round(num_df.mean(),1))
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                       1  37.770280 -122.433170             3        0.0
# 1                       2  37.744740 -122.420890             4        0.0
# 2                      13  37.765550 -122.452130             1        0.0
# 3                       2  37.775640 -122.436420             4        0.0
# 4                       2  37.760300 -122.421970             3        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                    9  37.791994 -122.410000             2        0.0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data6_iqr=cuali.copy()
data6_iqr=data5_iqr.fillna(round(cuali.mean()))
data6_iqr
# Out:
# <ipython-input-101-1c20573ef626>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data6_iqr=data5_iqr.fillna(round(cuali.mean()))
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                       1  37.770280 -122.433170             3        0.0
# 1                       2  37.744740 -122.420890             4        0.0
# 2                      13  37.765550 -122.452130             1        0.0
# 3                       2  37.775640 -122.436420             4        0.0
# 4                       2  37.760300 -122.421970             3        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                    9  37.791994 -122.410000             2        0.0
# ...

# %%
# Unimos los datas con el dataframe
limpios_iqr = pd.concat([num_df, cuali], axis=1)
limpios_iqr
# Out:
#       host_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                       1  37.770280 -122.433170             3        0.0
# 1                       2  37.744740 -122.420890             4        0.0
# 2                      13  37.765550 -122.452130             1        0.0
# 3                       2  37.775640 -122.436420             4        0.0
# 4                       2  37.760300 -122.421970             3        0.0
# ...                   ...        ...         ...           ...        ...
# 6931                    9  37.791994 -122.410000             2        0.0
# 6932                    1  37.763060 -122.432023             2        0.0
# 6933                    1  37.777633 -122.416478             1        0.0
# 6934                    3  37.738325 -122.396603             2        0.0
# 6935                    2  37.786442 -122.457006             2        0.0
#
#       bedrooms  beds    price  minimum_nights  maximum_nights  ...  \
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=limpios_iqr.isnull().sum()
valores_nulos
# Out:
# host_listings_count      0
# latitude                 0
# longitude                0
# accommodates             0
# bathrooms                0
#                         ..
# calendar_last_scraped    0
# first_review             0
# last_review              0
# license                  0
# instant_bookable         0
# Length: 75, dtype: int64

# %%
#Convertir DataFrame a CSV
limpios_iqr.to_csv("valores_nulos_california.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("valores_nulos_california.csv")
